# %%
import urllib
from bs4 import BeautifulSoup 
import pandas as pd

# %%
def url2html(url):
    req = urllib.request.Request(url)
    res = urllib.request.urlopen(req)
    html = res.read()
    return html

# %%
url = 'http://race.netkeiba.com/?pid=race_old&id=c201706050811'
html = url2html(url)
soup = BeautifulSoup(html, 'html.parser')

# %%
table = soup.find('table')
#soup.select('.race_table_old nk_tb_common')

# %%
[ th.text for th in table.select('th')]
# Out:
# ['あなたの印※',
#  '馬名',
#  '性齢',
#  '負担重量',
#  '騎手',
#  '厩舎',
#  '予想オッズ',
#  '人気',
#  'お気に入り馬',
#  '登録',
#  'あなたのメモ']

# %%
data = []
for tr in table.select('tr'):
    tds = [ td.text.rsplit()[0] for td in tr.select('td')[1:-2]]
    if len(tds):
        data.append(tds)
data
# Out:
# [['カレンミロティック', 'セ9', '57.0', '川田', '平田', '290.1', '15'],
#  ['キタサンブラック', '牡5', '57.0', '武豊', '清水久', '2.3', '1'],
#  ['クイーンズリング', '牝5', '55.0', 'Ｃ．ルメール', '吉村', '82.5', '13'],
#  ['サウンズオブアース', '牡6', '57.0', 'Ｃ．デムーロ', '藤岡', '54.5', '10'],
#  ['サクラアンプルール', '牡6', '57.0', '蛯名', '金成', '56.9', '11'],
#  ['サトノクラウン', '牡5', '57.0', 'Ｒ．ムーア', '堀', '11.8', '5'],
#  ['サトノクロニクル', '牡3', '55.0', '戸崎', '池江', '121.5', '14'],
#  ['シャケトラ', '牡4', '57.0', '福永', '角居', '23.8', '7'],
#  ['シュヴァルグラン', '牡5', '57.0', 'Ｈ．ボウマン', '友道', '5.9', '3'],
#  ['スワーヴリチャード', '牡3', '55.0', 'Ｍ．デムーロ', '庄野', '3.1', '2'],
#  ['トーセンビクトリー', '牝5', '55.0', '田辺', '角居', '315.5', '16'],
#  ['ブレスジャーニー', '牡3', '55.0', '三浦', '佐々木', '80.3', '12'],
#  ['ミッキークイーン', '牝5', '55.0', '浜中', '池江', '9.5', '4'],
#  ['ヤマカツエース', '牡5', '57.0', '池添', '池添兼', '24.7', '8'],
#  ['ルージュバック', '牝5', '55.0', '北村宏', '大竹', '38.2', '9'],
#  ['レインボーライン', '牡4', '57.0', '岩田', '浅見', '23.1', '6']]

# %%
cols = [ th.text for th in table.select('th')][1:8]
df = pd.DataFrame(data, columns=cols)

# %%
df
# Out:
#            馬名  性齢  負担重量      騎手   厩舎  予想オッズ  人気
# 0   カレンミロティック  セ9  57.0      川田   平田  290.1  15
# 1    キタサンブラック  牡5  57.0      武豊  清水久    2.3   1
# 2    クイーンズリング  牝5  55.0  Ｃ．ルメール   吉村   82.5  13
# 3   サウンズオブアース  牡6  57.0  Ｃ．デムーロ   藤岡   54.5  10
# 4   サクラアンプルール  牡6  57.0      蛯名   金成   56.9  11
# 5     サトノクラウン  牡5  57.0   Ｒ．ムーア    堀   11.8   5
# 6    サトノクロニクル  牡3  55.0      戸崎   池江  121.5  14
# 7       シャケトラ  牡4  57.0      福永   角居   23.8   7
# 8    シュヴァルグラン  牡5  57.0  Ｈ．ボウマン   友道    5.9   3
# 9   スワーヴリチャード  牡3  55.0  Ｍ．デムーロ   庄野    3.1   2
# 10  トーセンビクトリー  牝5  55.0      田辺   角居  315.5  16
# 11   ブレスジャーニー  牡3  55.0      三浦  佐々木   80.3  12
# 12   ミッキークイーン  牝5  55.0      浜中   池江    9.5   4
# 13    ヤマカツエース  牡5  57.0      池添  池添兼   24.7   8
# 14    ルージュバック  牝5  55.0     北村宏   大竹   38.2   9
# 15   レインボーライン  牡4  57.0      岩田   浅見   23.1   6

# %%
def df_race(race_id):
    url = 'http://race.netkeiba.com/?pid=race_old&id={}'.format(race_id)
    html = url2html(url)
    soup = BeautifulSoup(html, 'html.parser')
    table = soup.find('table')
    data = []
    for tr in table.select('tr'):
        tds = [ td.text.rsplit()[0] for td in tr.select('td')[1:-2]]
        if len(tds):
            data.append(tds)
    cols = [ th.text for th in table.select('th')][1:8]
    df = pd.DataFrame(data, columns=cols)
    return df

# %%
df_race('c201706050809')
# Out:
#            馬名  性齢  負担重量     騎手   厩舎  予想オッズ  人気
# 0        イチダイ  牡4  57.0     三浦   柄崎   24.0   8
# 1    ウインヴォラーレ  牡4  57.0     松岡   手塚    8.6   5
# 2   エニグマバリエート  牡5  54.0     福永   戸田   75.9  14
# 3    ギブアンドテイク  セ6  53.0     岩田  二ノ宮  455.3  18
# 4     コスモジャーベ  牡4  55.0    柴田大  和田雄   11.4   6
# 5     コスモピクシス  牝4  53.0     津村   中野   53.6  10
# 6    コスモボアソルテ  牡5  53.0    三津谷   蛯名  227.7  17
# 7   サブライムカイザー  牡5  56.0    吉田豊  池上弘  182.1  16
# 8       ジャッキー  牡3  53.0     津村  高橋祥    4.6   2
# 9     ジャポニカーラ  牝5  52.0    石橋脩   勢司   56.9  12
# 10  ステイブラビッシモ  牡4  56.0     丸山  久保田   14.9   7
# 11    タケルラムセス  牡5  54.0     勝浦   田村  151.8  15
# 12     チャロネグロ  牡3  55.0     田辺  大和田    2.7   1
# 13  フェイズベロシティ  牝4  54.0  Ｃデムーロ   萩原   50.6   9
# 14    プライムセラー  セ4  55.0    石橋脩  和田郎    4.9   3
# 15   マイネルフレスコ  牡6  54.0     丹内  高橋祥    7.2   4
# 16   マイネルレオーネ  牡5  55.0    石橋脩  清水久   75.9  13
# 17      マナローラ  牝3  51.0     松若   鮫島   53.6  11
